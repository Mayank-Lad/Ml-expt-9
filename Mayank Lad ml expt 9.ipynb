# %% [markdown]
# Name: Mayank Lad
# Rollno.: 21102B0063
# Batch 4
# BE CMPN-B

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/optdigits/optdigits.tra"
data = pd.read_csv(url, header=None)

X = data.iloc[:, :-1]
y = data.iloc[:, -1]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

df_pca = pd.DataFrame(data=X_pca, columns=['PC1', 'PC2'])
df_pca['Digit'] = y

plt.figure(figsize=(10, 7))
sns.scatterplot(x='PC1', y='PC2', hue='Digit', palette='Set2', data=df_pca)
plt.title('PCA of UCI Optical Digits Dataset')
plt.show()

print(f'Explained variance ratio: {pca.explained_variance_ratio_}')
# Out:
# Explained variance ratio: [0.11639052 0.10515794]
